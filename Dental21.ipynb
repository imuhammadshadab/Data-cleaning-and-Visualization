# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data =pd.read_csv("fake_clinic_data_extract_test (1).csv")

# %%
data.head()
# Out:
#    Year     Month  Day clinic_name  patient_id  practitioner_id  \
# 0  2021  December   30    clinic_2       70172             1030
# 1  2021  December   29    clinic_1       53371              756
# 2  2021  December   29    clinic_2       69545             1030
# 3  2021  December   27    clinic_1       43859              756
# 4  2021  December   23    clinic_1       69303              756
#
#    appointment_duration_min  revenues_from_appointment
# 0                        30                      98.13
# 1                        15                      65.13
# 2                        30                     105.18
# 3                        30                      58.11
# 4                        30                     119.00

# %% [markdown]
# check the missing values

# %%
# missing_values_count = data.isnull().sum()
# missing_values_count[0:4072]

# %% [markdown]
# how many total missing values do we have?
# percent of data that is missing

# %%
# total_cells = np.product(data.shape)
# total_missing = missing_values_count.sum()

# percent_missing = (total_missing/total_cells) * 100
# print(percent_missing)

# %% [markdown]
# fill the missing value through a median

# %%
x = data["revenues_from_appointment"].median()

data["revenues_from_appointment"].fillna(x, inplace = True)

# %% [markdown]
# Save the changes

# %%
# data.to_csv('fake_clinic_data_extract_test (1).csv')

# %% [markdown]
# Check the Null value

# %%
# print(data.isnull().sum())
# Out:
# Year                         0
# Month                        0
# Day                          0
# clinic_name                  0
# patient_id                   0
# practitioner_id              0
# appointment_duration_min     0
# revenues_from_appointment    0
# dtype: int64

# %%
import plotly.express as px
import plotly.graph_objects as go
fig = px.bar(data, x="Month", y="revenues_from_appointment", color="clinic_name",barmode="group",title='Revenue month-wise and Clinic-wise')
fig.show()
# Out:
# <div>                            <div id="b25f0820-c4e4-43de-9f70-da07c9d11c64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b25f0820-c4e4-43de-9f70-da07c9d11c64")) {                    Plotly.newPlot(                        "b25f0820-c4e4-43de-9f70-da07c9d11c64",                        [{"alignmentgroup":"True","hovertemplate":"clinic_name=clinic_2<br>Month=%{x}<br>revenues_from_appointment=%{y}<extra></extra>","legendgroup":"clinic_2","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"clinic_2","offsetgroup":"clinic_2","orientation":"v","showlegend":true,"textposition":"auto","x":["December","December","December","December","December","December","December","December","December","December","December","December","December","December","De
# ...

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=data, x="appointment_duration_min", y="revenues_from_appointment",hue='clinic_name',).set(title='Plot Between appointment duration and revenues in each Clinic')
# Out:
# [Text(0.5, 1.0, 'Plot Between appointment duration and revenues in each Clinic')]
